# %% [markdown]
# # Import Necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/likhithareddykesara/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Import IOWA Liquor Sales Datset

# %%
df = pd.read_csv("/Users/likhithareddykesara/Desktop/Projects/IOWA liquor Sales/dataset/Iowa_Liquor_Sales.csv")
df.shape
# Out:
# /var/folders/7x/k4kt73kx58ndk6rmm4bn6qdm0000gn/T/ipykernel_33011/3792390817.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/likhithareddykesara/Desktop/Projects/IOWA liquor Sales/dataset/Iowa_Liquor_Sales.csv")
# (12591077, 24)

# %% [markdown]
# ### Interpretation:
# - Shape of the dataset is 12.6 million rows and 24 columns

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0        S29198800001  11/20/2015          2191
# 1        S29195400002  11/21/2015          2205
# 2        S29050300001  11/16/2015          3549
# 3        S28867700001  11/04/2015          2513
# 4        S29050800001  11/17/2015          3942
#
#                          Store Name              Address          City  \
# 0                    Keokuk Spirits            1013 MAIN        KEOKUK
# 1            Ding's Honk And Holler     900 E WASHINGTON      CLARINDA
# 2              Quicker Liquor Store         1414 48TH ST  FORT MADISON
# 3  Hy-Vee Food Store #2 / Iowa City       812  S 1ST AVE     IOWA CITY
# 4                  Twin Town Liquor  104 HIGHWAY 30 WEST        TOLEDO
#
#   Zip Code                                     Store Location  County Number  \
# 0    52632    1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)           56.0
# 1    51632  900 E WASHINGTON\nCLARINDA 51632\n(40.739238, ...           73.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12591077 entries, 0 to 12591076
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Invoice/Item Number    object
#  1   Date                   object
#  2   Store Number           int64
#  3   Store Name             object
#  4   Address                object
#  5   City                   object
#  6   Zip Code               object
#  7   Store Location         object
#  8   County Number          float64
#  9   County                 object
#  10  Category               float64
#  11  Category Name          object
#  12  Vendor Number          float64
#  13  Vendor Name            object
#  14  Item Number            int64
#  15  Item Description       object
#  16  Pack                   int64
#  17  Bottle Volume (ml)     int64
#  18  State Bottle Cost      object
#  19  State Bottle Retail    object
#  20  Bottles Sold           int64
# ...

# %% [markdown]
# ## Convert Date to DateTime format

# %%
df['Date']=pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12591077 entries, 0 to 12591076
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Invoice/Item Number    object
#  1   Date                   datetime64[ns]
#  2   Store Number           int64
#  3   Store Name             object
#  4   Address                object
#  5   City                   object
#  6   Zip Code               object
#  7   Store Location         object
#  8   County Number          float64
#  9   County                 object
#  10  Category               float64
#  11  Category Name          object
#  12  Vendor Number          float64
#  13  Vendor Name            object
#  14  Item Number            int64
#  15  Item Description       object
#  16  Pack                   int64
#  17  Bottle Volume (ml)     int64
#  18  State Bottle Cost      object
#  19  State Bottle Retail    object
#  20  Bottles Sold           int64
# ...

# %%
print(df['Date'].min())
print(df['Date'].max())
# Out:
# 2012-01-03 00:00:00
# 2017-10-31 00:00:00

# %% [markdown]
# ### Interpretation:
# - The dataset comprises liquor sales transaction records from 2012 to 2017

# %%
df['Store Number'] = df['Store Number'].astype('O')

# %%
df['County Number'] = df['County Number'].astype('O')

# %%
df['Category'] = df['Category'].astype('O')

# %%
df['Vendor Number'] = df['Vendor Number'].astype('O')

# %%
df['Item Number'] = df['Item Number'].astype('O')

# %%
df['State Bottle Cost'] = df['State Bottle Cost'].str.replace('$','')

# %%
df['State Bottle Cost'].head()
# Out:
# 0    18.09
# 1    18.09
# 2     6.40
# 3    35.55
# 4     6.40
# Name: State Bottle Cost, dtype: object

# %%
df['State Bottle Cost'] = df['State Bottle Cost'].astype('float')

# %%
df['State Bottle Retail'] = df['State Bottle Retail'].str.replace('$','')

# %%
df['State Bottle Retail'].head()
# Out:
# 0    27.14
# 1    27.14
# 2     9.60
# 3    53.34
# 4     9.60
# Name: State Bottle Retail, dtype: object

# %%
df['State Bottle Retail'] = df['State Bottle Retail'].astype('float')

# %%
df['Sale (Dollars)'] = df['Sale (Dollars)'].str.replace('$','')

# %%
df['Sale (Dollars)'] = df['Sale (Dollars)'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12591077 entries, 0 to 12591076
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Invoice/Item Number    object
#  1   Date                   datetime64[ns]
#  2   Store Number           object
#  3   Store Name             object
#  4   Address                object
#  5   City                   object
#  6   Zip Code               object
#  7   Store Location         object
#  8   County Number          object
#  9   County                 object
#  10  Category               object
#  11  Category Name          object
#  12  Vendor Number          object
#  13  Vendor Name            object
#  14  Item Number            object
#  15  Item Description       object
#  16  Pack                   int64
#  17  Bottle Volume (ml)     int64
#  18  State Bottle Cost      float64
#  19  State Bottle Retail    float64
#  20  Bottles Sold           int64
# ...

# %% [markdown]
# # Checking for Missing values

# %%
df.isnull().sum()
# Out:
# Invoice/Item Number          0
# Date                         0
# Store Number                 0
# Store Name                   0
# Address                   2376
# City                      2375
# Zip Code                  2420
# Store Location            2375
# County Number            79178
# County                   79178
# Category                  8020
# Category Name            16086
# Vendor Number                3
# Vendor Name                  1
# Item Number                  0
# Item Description             0
# Pack                         0
# Bottle Volume (ml)           0
# State Bottle Cost           10
# State Bottle Retail         10
# Bottles Sold                 0
# Sale (Dollars)              10
# Volume Sold (Liters)         0
# Volume Sold (Gallons)        0
# dtype: int64

# %% [markdown]
# # Checking for Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Invoice/Item Number', 'Date', 'Store Number', 'Store Name', 'Address',
#        'City', 'Zip Code', 'Store Location', 'County Number', 'County',
#        'Category', 'Category Name', 'Vendor Number', 'Vendor Name',
#        'Item Number', 'Item Description', 'Pack', 'Bottle Volume (ml)',
#        'State Bottle Cost', 'State Bottle Retail', 'Bottles Sold',
#        'Sale (Dollars)', 'Volume Sold (Liters)', 'Volume Sold (Gallons)'],
#       dtype='object')

# %% [markdown]
# # Renaming Column names

# %%
df = df.rename(columns={'Invoice/Item Number':'Invoice_Item_Number','Store Number':'Store_Number',
                   'Store Name':'Store_Name','Zip Code':'Zip_Code','Store Location':'Store_Location',
                   'County Number':'County_Number','Category Name':'Category_Name',
                   'Vendor Number':'Vendor_Number','Vendor Name':'Vendor_Name',
                   'Item Number':'Item_Number','Item Description':'Item_Description',
                   'Bottle Volume (ml)':'Bottle_Volume','State Bottle Cost':'State_Bottle_Cost',
                   'State Bottle Retail':'State_Bottle_Retail','Bottles Sold':'Bottles_Sold',
                  'Sale (Dollars)':'Sale_in_dollars','Volume Sold (Liters)':'Volume_Sold_liters',
                  'Volume Sold (Gallons)':'Volume_Sold_Gallons'})

# %%
df.head()
# Out:
#   Invoice_Item_Number       Date Store_Number  \
# 0        S29198800001 2015-11-20         2191
# 1        S29195400002 2015-11-21         2205
# 2        S29050300001 2015-11-16         3549
# 3        S28867700001 2015-11-04         2513
# 4        S29050800001 2015-11-17         3942
#
#                          Store_Name              Address          City  \
# 0                    Keokuk Spirits            1013 MAIN        KEOKUK
# 1            Ding's Honk And Holler     900 E WASHINGTON      CLARINDA
# 2              Quicker Liquor Store         1414 48TH ST  FORT MADISON
# 3  Hy-Vee Food Store #2 / Iowa City       812  S 1ST AVE     IOWA CITY
# 4                  Twin Town Liquor  104 HIGHWAY 30 WEST        TOLEDO
#
#   Zip_Code                                     Store_Location County_Number  \
# 0    52632    1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)          56.0
# 1    51632  900 E WASHINGTON\nCLARINDA 51632\n(40.739238, ...          73.0
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
print(df.groupby('Category')['Category_Name'].unique().to_frame().shape)
# Out:
# (107, 1)

# %%
print(df.groupby('Category')['Category_Name'].unique().to_frame().head(30))
# Out:
#                                                Category_Name
# Category
# 101220.0                                               [nan]
# 1011100.0               [BLENDED WHISKIES, Blended Whiskies]
# 1011200.0  [STRAIGHT BOURBON WHISKIES, Straight Bourbon W...
# 1011250.0                   [SINGLE BARREL BOURBON WHISKIES]
# 1011300.0  [TENNESSEE WHISKIES, Single Barrel Bourbon Whi...
# 1011400.0      [BOTTLED IN BOND BOURBON, Tennessee Whiskies]
# 1011500.0   [STRAIGHT RYE WHISKIES, Bottled in Bond Bourbon]
# 1011600.0             [CORN WHISKIES, Straight Rye Whiskies]
# 1011700.0                               [nan, Corn Whiskies]
# 1011800.0                         [Iowa Distillery Whiskies]
# 1012100.0             [CANADIAN WHISKIES, Canadian Whiskies]
# 1012200.0                 [SCOTCH WHISKIES, Scotch Whiskies]
# 1012210.0                               [SINGLE MALT SCOTCH]
# 1012300.0               [IRISH WHISKIES, Single Malt Scotch]
# ...

# %% [markdown]
# - There are 107 liquor categories
# - However, few of the categories names are same but assigned with different category number

# %%
df['Category_Name'].nunique()
# Out:
# 130

# %%
# Changing Category_Name based on the Category Number
df.loc[df['Category_Name'] == 'Single Barrel Bourbon Whiskies', 'Category'] = 1011300.0
df.loc[df['Category_Name'] == 'Temporary & Specialty Packages', 'Category'] = 1700000.0
df.loc[df['Category_Name'] == 'Corn Whiskies', 'Category'] = 1011700.0
df.loc[df['Category_Name'] == 'American Vodkas', ['Category', 'Category_Name']] = 1031000.0, 'American Vodka' 
df.loc[df['Category_Name'] == 'Straight Rye Whiskies', 'Category'] = 1011600.0
df.loc[df['Category_Name'] == 'Bottled In Bond Bourbon', 'Category'] = 1011500.0
df.loc[df['Category_Name'] == 'Tennessee Whiskies', 'Category'] = 1011400.0
df.loc[df['Category_Name'] == 'Single Malt Scotch', 'Category'] = 1012210.0
df.loc[df['Category_Name'] == 'Irish Whiskies', 'Category'] = 1012300.0
df.loc[df['Category_Name'] == 'Flavored Gins', 'Category'] = 1041000.0
df.loc[df['Category_Name'] == 'Cocktails /Rtd', 'Category'] = 1070000.0
df.loc[df['Category_Name'] == 'Spiced Rum', 'Category'] = 1062310.0
df.loc[df['Category_Name'] == 'Imported Vodkas', ['Category', 'Category_Name']] = 1032000.0, 'American Vodka'
df.loc[df['Category_Name'] == 'Imported Vodka', 'Category'] = 1032000.0
df.loc[df['Category_Name'] == 'Flavored Rum', 'Category'] = 1062500.0
df.loc[df['Category_Name'] == 'Cocktails /Rtd', 'Category_Name'] = 'Cocktails / Rtd'
df.loc[df['Category_Name'] == 'Coffee Liqueurs', 'Category'] = 1081030.0
df.loc[df['Category_Name'] == 'American Dry Gins', 'Category'] = 1041100.0
df.loc[df['Category_Name'] == 'American Vodka', 'Category'] = 1031000.0
df.loc[df['Category_Name'] == 'American Sloe Gins', 'Category'] = 1041300.0
df.loc[df['Category_Name'] == 'American Cordials & Liqueurs', 'Category'] = 1081000.0
df.loc[df['Category_Name'] == 'Imported Distilled Spirits Specialty', 'Category'] = 1092000.0
df.loc[df['Category_Name'] == 'Imported Cordials & Liqueur', ['Category', 'Category_Name']] = 1082000.0, 'Imported Cordials & Liqueurs' 
df.loc[df['Category_Name'] == 'American Cordials & Liqueur', ['Category', 'Category_Name']] = 1081000, 'American Cordials & Liqueurs' 
df.loc[df['Category_Name'] == 'Imported Distilled Spirit Specialty', ['Category', 'Category_Name']] = 1092000.0, 'Imported Distilled Spirits Specialty'
df.loc[df['Category_Name'] == 'Temporary &  Specialty Packages', 'Category_Name'] = 'Temporary & Specialty Packages'
df.loc[df['Category_Name'] == 'Vodka Flavored', 'Category_Name'] = 'American Flavored Vodka'
df.loc[df['Category_Name'] == 'American Vodka Flavored', 'Category_Name'] = 'American Flavored Vodka'
df.loc[(df['Category_Name'] == 'Tequila')|(df['Category_Name'] == 'Mixto'), 'Category_Name'] = 'Mixto Tequila'
df.loc[df['Category_Name'] == 'Imported Vodka  Misc', 'Category_Name'] = 'Imported Flavored Vodka'
df.loc[df['Category_Name'] == 'American Gins', 'Category_Name'] = 'Flavored Gins'
df.loc[(df['Category_Name'] == 'Apricot Brandies')|(df['Category_Name'] == 'American Brandies'), 'Category_Name'] = 'Apricot Brandies (American Brandies)'
df.loc[(df['Category_Name'] == 'Jamaica Rum')|(df['Category_Name'] == 'Gold Rum'), 'Category_Name'] = 'Jamaica Rum (Gold Rum)'
df.loc[(df['Category_Name'] == 'Puerto Rico & Virgin Islands Rum')|(df['Category_Name'] == 'White Rum'), 'Category_Name'] = 'Puerto Rico & Virgin Islands Rum (White Rum)'
df.loc[(df['Category_Name'] == 'Triple Sec') & (df['Category'] == 1081400.0), 'Category_Name'] = 'American Schnapps (Triple Sec)'
df.loc[(df['Category_Name'] == 'American Schnapps') & (df['Category'] == 1081400.0), 'Category_Name'] = 'American Schnapps (Triple Sec)'

# %%
df['Category_Name'].nunique()
# Out:
# 124

# %% [markdown]
# - Combined redundant category names and we can observe 124 unique categories now, before it was 130.

# %%
print(df.groupby('Category')['Category_Name'].unique().to_frame().head(30))
# Out:
#                                                Category_Name
# Category
# 101220.0                                               [nan]
# 1011100.0               [BLENDED WHISKIES, Blended Whiskies]
# 1011200.0  [STRAIGHT BOURBON WHISKIES, Straight Bourbon W...
# 1011250.0                   [SINGLE BARREL BOURBON WHISKIES]
# 1011300.0  [TENNESSEE WHISKIES, Single Barrel Bourbon Whi...
# 1011400.0      [BOTTLED IN BOND BOURBON, Tennessee Whiskies]
# 1011500.0   [STRAIGHT RYE WHISKIES, Bottled in Bond Bourbon]
# 1011600.0             [CORN WHISKIES, Straight Rye Whiskies]
# 1011700.0                               [nan, Corn Whiskies]
# 1011800.0                         [Iowa Distillery Whiskies]
# 1012100.0             [CANADIAN WHISKIES, Canadian Whiskies]
# 1012200.0                 [SCOTCH WHISKIES, Scotch Whiskies]
# 1012210.0           [SINGLE MALT SCOTCH, Single Malt Scotch]
# 1012300.0                   [IRISH WHISKIES, Irish Whiskies]
# ...

# %%
print(df.groupby('Store_Number')['Store_Name'].unique().to_frame().shape)
# Out:
# (1884, 1)

# %%
print(df.groupby('Store_Number')['Store_Name'].unique().to_frame().head(10))
# Out:
#                                                      Store_Name
# Store_Number
# 2106                              [Hillstreet News and Tobacco]
# 2113                                           [Jamboree Foods]
# 2130                                     [Sycamore Convenience]
# 2132                                         [Spirits and Such]
# 2152                                       [Dugans Supermarket]
# 2161                                       [Huber's Store Inc.]
# 2178          [Double "D" Liquor Store, "Double ""D"" Liquor...
# 2190                                [Central City Liquor, Inc.]
# 2191                                           [Keokuk Spirits]
# 2200                                         [Sac Liquor Store]

# %% [markdown]
# - There are total 1884 unique stores

# %%
df['Store_Name'].nunique()
# Out:
# 1952

# %%
df.loc[df['Store_Name'] == 'Kum & Go 202 / 4Th St Waukee', ['Store_Name', 'City']] = 'Kum & Go 202', 'Waukee'
df.loc[df['Store_Name'] == 'Caseys General Store  2783/ Urband', ['Store_Name', 'City']] = 'Caseys General Store 2783', 'Urbandale'
df.loc[df['Store_Name'] == 'Caseys General Store 1125 / Humest', ['Store_Name', 'City']] = 'Caseys General Store 1125', 'Humeston'
df.loc[df['Store_Name'] == 'Kum & Go  532/ West Dsm', ['Store_Name', 'City']] = 'Kum & Go  532', 'West Des Moines'
df.loc[df['Store_Name'] == 'Fareway Stores 703 / Humbolt', ['Store_Name', 'City']] = 'Fareway Stores 703', 'Humboldt'
df.loc[df['Store_Name'] == 'D And S Grocery', 'City'] = 'Melcherdallas'
df.loc[df['Store_Name'] == 'Point Liquor & Tobacco', 'City'] = 'Cedar Rapids'
df.loc[df['Store_Name'] == 'North American Spirits', 'City'] = 'Urbandale'
df.loc[(df['Store_Name'] == 'The Secret Cellar') & (df['Date'] < '2017-09-12'), 'City'] = 'Swisher'
df.loc[(df['Store_Name'] == 'The Secret Cellar') & (df['Date'] >= '2017-09-12'), 'City'] = 'Shueyville'
df.loc[df['Store_Name'] == 'Caseys General Store  2560', 'City'] = 'Ames'
df.loc[df['Store_Name'] == 'Gameday Liquor', 'City'] = 'Glenwood'
df.loc[df['Store_Name'] == 'Liquor And Grocery Depot', 'City'] = 'Marshalltown'
df.loc[df['Store_Name'] == 'Express Mart', 'City'] = 'Muscatine'
df.loc[df['Store_Name'] == 'Av Superstop', 'City'] = 'Des Moines'
df.loc[df['Store_Name'] == 'U S Gas', 'City'] = 'Des Moines'
df.loc[df['Store_Name'] == 'River Mart', 'City'] = 'West Burlington'
df.loc[df['Store_Name'] == 'Caseys General Store 1548 / Ankeny', 'City'] = 'Ankeny'
df.loc[df['Store_Name'] == 'Caseys General Store 3075 / Ankeny', 'City'] = 'Ankeny'
df.loc[df['Store_Name'] == 'Hyvee Wine And Spirits / Estherville', 'City'] = 'Estherville'
df.loc[df['Store_Name'] == 'Caseys General Store 3508/ Marsha', 'City'] = 'Marsha'
df.loc[df['Store_Name'] == 'Fareway Stores 151 / Cedar Rapids', 'City'] = 'Cedar Rapids'
df.loc[df['Store_Name'] == 'Mmdg Spirits / Ames', 'City'] = 'Ames'
df.loc[df['Store_Name'] == 'Kum & Go 438 / Muscatine', 'City'] = 'Muscatine'
df.loc[df['Store_Name'] == 'Caseys General Store 1567 / Anita', 'City'] = 'Anita'
df.loc[df['Store_Name'] == 'Caseys General Store 1503 / Tabor', 'City'] = 'Tabor'
df.loc[df['Store_Name'] == 'Hyvee Food And Drug 6 / Cedar Rapids', 'City'] = 'Cedar Rapids'
df.loc[df['Store_Name'] == 'Caseys General Store 1365 / Paullina', 'City'] = 'Paullina'
df.loc[df['Store_Name'] == 'Caseys General Store 1680 / Adel', 'City'] = 'Adel'
df.loc[df['Store_Name'] == 'Caseys General Store  2598/ Pella', 'City'] = 'Pella'
df.loc[df['Store_Name'] == 'Caseys General Store 1617 / Jefferson', 'City'] = 'Jefferson'
df.loc[df['Store_Name'] == 'Indy 66 West 929 / Indianola', 'City'] = 'Indianola'
df.loc[df['Store_Name'] == 'Kum & Go 4098 / Windsor Heights', 'City'] = 'Windsor Heights'
df.loc[df['Store_Name'] == 'Jeffs Market / Wilton', 'City'] = 'Wilton'
df.loc[df['Store_Name'] == 'Kum & Go 502 / Iowa City', 'City'] = 'Iowa City'
df.loc[df['Store_Name'] == 'Kum & Go 201 / Coralville', 'City'] = 'Coralville'
df.loc[df['Store_Name'] == 'Kum & Go 768 / Hospers', 'City'] = 'Hospers'
df.loc[df['Store_Name'] == 'Caseys General Store  2417/ Newton', 'City'] = 'Newton'
df.loc[df['Store_Name'] == 'Caseys General Store 1493 / Van Meter', 'City'] = 'Van Meter'
df.loc[df['Store_Name'] == 'Caseys General Store 1684 / Emmetsburg', 'City'] = 'Emmetsburg'
df.loc[df['Store_Name'] == 'Kum & Go 521  /  Coralville', 'City'] = 'Coralville'
df.loc[df['Store_Name'] == 'Kum & Go 540 / Waukee', 'City'] = 'Waukee'
df.loc[df['Store_Name'] == 'Hyvee Drugstore / Council Bluffs', 'City'] = 'Council Bluffs'
df.loc[df['Store_Name'] == 'Fareway Store  167/Johnston', 'City'] = 'Johnston'
df.loc[df['Store_Name'] == 'Fas Mart  5150/ Cedar Rapids', 'City'] = 'Cedar Rapids'
df.loc[df['Store_Name'] == 'Kum & Go 83 / Casey', 'City'] = 'Casey'
df.loc[df['Store_Name'] == 'Kum & Go  119/ Northwood', 'City'] = 'Northwood'

# %%
# Splitting Store_Name at ' / ' to retain only the first part
df['Store_Name'] = df['Store_Name'].astype(str).str.split(' / ', n=1).str[0]

# %%
df['Store_Name'].nunique()
# Out:
# 1671

# %% [markdown]
# - Combined redundant Store names and we can observe 1671 unique Stores now, before it was 1952.

# %%
print(df.groupby('Vendor_Number')['Vendor_Name'].unique().to_frame().shape)
# Out:
# (271, 1)

# %%
print(df.groupby('Vendor_Number')['Vendor_Name'].unique().to_frame().head(10))
# Out:
#                                                   Vendor_Name
# Vendor_Number
# 10.0                [A Hardy / U.S.A., Ltd., A HARDY USA LTD]
# 14.0                             [Adamba Imports Int'l, Inc.]
# 27.0                      [Anheuser-Busch/Longtail Libations]
# 33.0                               [Bmc Imports, BMC Imports]
# 35.0                  [Bacardi U.S.A., Inc., BACARDI USA INC]
# 51.0                            [Barrel House Distilling Co.]
# 55.0           [Sazerac North America, SAZERAC NORTH AMERICA]
# 61.0                       [Biagio Cru And Estate Wines, LLC]
# 65.0                                        [Jim Beam Brands]
# 68.0                              [Belmont Farms Of Va., Inc]

# %% [markdown]
# - There are total 271 vendors in this dataset

# %%
print(df.groupby('Item_Number')['Item_Description'].unique().to_frame().shape)
# Out:
# (7395, 1)

# %%
print(df.groupby('Item_Number')['Item_Description'].unique().to_frame().head(10))
# Out:
#                                               Item_Description
# Item_Number
# 101          [Stolichnaya Premium 80prf w/2 Stemless Martin...
# 102                         [Bushmills 750ml w/Blackbush 50ml]
# 104                   [Broker's Gin Holiday w/1 Collins Glass]
# 107                  [Bushmills Black w/Rubber Ice Ball Molds]
# 108                             [Midnight Moon Cran-Apple Pie]
# 114                              [Belvedere Pure Red w/Shaker]
# 115                            [Crown Royal w/Glass & Coaster]
# 122                             [Deep Eddy Vodka w/2 Tin Cups]
# 124                          [Deep Eddy 750ml Vodka w/3-50mls]
# 127                             [Deep Eddy Lemon w/2 Tin Cups]

# %% [markdown]
# - There are total 7395 unique Items

# %%
(df.groupby('City')['City'].unique()).values.tolist()
# Out:
# [array(['ACKLEY'], dtype=object),
#  array(['ADAIR'], dtype=object),
#  array(['ADEL'], dtype=object),
#  array(['AFTON'], dtype=object),
#  array(['AKRON'], dtype=object),
#  array(['ALBIA'], dtype=object),
#  array(['ALDEN'], dtype=object),
#  array(['ALGONA'], dtype=object),
#  array(['ALLISON'], dtype=object),
#  array(['ALTA'], dtype=object),
#  array(['ALTA VISTA'], dtype=object),
#  array(['ALTON'], dtype=object),
#  array(['ALTOONA'], dtype=object),
#  array(['ALVORD'], dtype=object),
#  array(['AMES'], dtype=object),
#  array(['ANAMOSA'], dtype=object),
#  array(['ANITA'], dtype=object),
#  array(['ANKENY'], dtype=object),
#  array(['ANTHON'], dtype=object),
#  array(['ARLINGTON'], dtype=object),
#  array(['ARMSTRONG'], dtype=object),
#  array(["ARNOLD'S PARK"], dtype=object),
#  array(['ARNOLDS PARK'], dtype=object),
#  array(['ATLANTIC'], dtype=object),
#  array(['AUDUBON'], dtype=object),
#  array(['AURELIA'], dtype=object),
#  array(['AVOCA'], dtype=object),
# ...

# %%
df.loc[df['City'] == 'Clearlake', 'City'] = 'Clear Lake'
df.loc[df['City'] == 'Otumwa', 'City'] = 'Ottuwma'
df.loc[df['City'] == 'Ottumwa', 'City'] = 'Ottuwma'
df.loc[df['City'] == 'Leclaire', 'City'] = 'Le Claire'
df.loc[df['City'] == 'Grand Mounds', 'City'] = 'Grand Mound'

# %%
df['City'].nunique()
# Out:
# 787

# %% [markdown]
# - There are 787 unique cities in total in the IOWA state.

# %%
df.isnull().sum()
# Out:
# Invoice_Item_Number        0
# Date                       0
# Store_Number               0
# Store_Name                 0
# Address                 2376
# City                    1918
# Zip_Code                2420
# Store_Location          2375
# County_Number          79178
# County                 79178
# Category                8020
# Category_Name          16086
# Vendor_Number              3
# Vendor_Name                1
# Item_Number                0
# Item_Description           0
# Pack                       0
# Bottle_Volume              0
# State_Bottle_Cost         10
# State_Bottle_Retail       10
# Bottles_Sold               0
# Sale_in_dollars           10
# Volume_Sold_liters         0
# Volume_Sold_Gallons        0
# dtype: int64

# %%
df = df.drop(columns={'County_Number','County'})
df.isnull().sum()
# Out:
# Invoice_Item_Number        0
# Date                       0
# Store_Number               0
# Store_Name                 0
# Address                 2376
# City                    1918
# Zip_Code                2420
# Store_Location          2375
# Category                8020
# Category_Name          16086
# Vendor_Number              3
# Vendor_Name                1
# Item_Number                0
# Item_Description           0
# Pack                       0
# Bottle_Volume              0
# State_Bottle_Cost         10
# State_Bottle_Retail       10
# Bottles_Sold               0
# Sale_in_dollars           10
# Volume_Sold_liters         0
# Volume_Sold_Gallons        0
# dtype: int64

# %%
df = df.drop(columns={'Address','Zip_Code','Store_Location'})

# %% [markdown]
# - Hence, we have removed column 5 columns that are less important and has more null values

# %%
df.isnull().sum()
# Out:
# Invoice_Item_Number        0
# Date                       0
# Store_Number               0
# Store_Name                 0
# City                    1918
# Category                8020
# Category_Name          16086
# Vendor_Number              3
# Vendor_Name                1
# Item_Number                0
# Item_Description           0
# Pack                       0
# Bottle_Volume              0
# State_Bottle_Cost         10
# State_Bottle_Retail       10
# Bottles_Sold               0
# Sale_in_dollars           10
# Volume_Sold_liters         0
# Volume_Sold_Gallons        0
# dtype: int64

# %%
df.shape
# Out:
# (12591077, 19)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (12573065, 19)

# %%
df.isnull().sum()
# Out:
# Invoice_Item_Number    0
# Date                   0
# Store_Number           0
# Store_Name             0
# City                   0
# Category               0
# Category_Name          0
# Vendor_Number          0
# Vendor_Name            0
# Item_Number            0
# Item_Description       0
# Pack                   0
# Bottle_Volume          0
# State_Bottle_Cost      0
# State_Bottle_Retail    0
# Bottles_Sold           0
# Sale_in_dollars        0
# Volume_Sold_liters     0
# Volume_Sold_Gallons    0
# dtype: int64

# %% [markdown]
# - Hence we have dropped all the null values since there are very few null values in 6 of columns.

# %%
df.head()
# Out:
#    Invoice_Item_Number       Date Store_Number                  Store_Name  \
# 6         S28865700001 2015-11-09         2538        Hy-Vee Food Store #3
# 8         S29339300091 2015-11-30         2662       Hy-Vee Wine & Spirits
# 13        S28866900001 2015-11-11         3650  Spirits, Stogies and Stuff
# 18        S29134300126 2015-11-18         3723          J D Spirits Liquor
# 21        S29282800048 2015-11-23         2642     Hy-Vee Wine and Spirits
#
#          City   Category                   Category_Name Vendor_Number  \
# 6    WATERLOO  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
# 8   MUSCATINE  1701100.0  DECANTERS & SPECIALTY PACKAGES          65.0
# 13   HOLSTEIN  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
# 18      ONAWA  1081200.0                  CREAM LIQUEURS         305.0
# 21      PELLA  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
#
#                           Vendor_Name Item_Number  \
# ...

# %% [markdown]
# # Feature Engineering

# %%
df['State_Profit_per_bottle'] = df['State_Bottle_Retail']-df['State_Bottle_Cost']
df['State_Profit_total_bottle'] = df['State_Profit_per_bottle']*df['Bottles_Sold']

# %%
df.head()
# Out:
#    Invoice_Item_Number       Date Store_Number                  Store_Name  \
# 6         S28865700001 2015-11-09         2538        Hy-Vee Food Store #3
# 8         S29339300091 2015-11-30         2662       Hy-Vee Wine & Spirits
# 13        S28866900001 2015-11-11         3650  Spirits, Stogies and Stuff
# 18        S29134300126 2015-11-18         3723          J D Spirits Liquor
# 21        S29282800048 2015-11-23         2642     Hy-Vee Wine and Spirits
#
#          City   Category                   Category_Name Vendor_Number  \
# 6    WATERLOO  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
# 8   MUSCATINE  1701100.0  DECANTERS & SPECIALTY PACKAGES          65.0
# 13   HOLSTEIN  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
# 18      ONAWA  1081200.0                  CREAM LIQUEURS         305.0
# 21      PELLA  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
#
#                           Vendor_Name Item_Number  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## 10 liquor categories with highest sale

# %%
best10 = df.groupby(['Category_Name','Pack','Date'])['Sale_in_dollars'].sum().groupby(['Category_Name','Pack']).max().sort_values().groupby(['Category_Name']).sum().sort_values(ascending=False).reset_index()

# %%
best10
# Out:
#                       Category_Name  Sale_in_dollars
# 0                 CANADIAN WHISKIES        802533.78
# 1    DECANTERS & SPECIALTY PACKAGES        747101.19
# 2                        SPICED RUM        536100.96
# 3                    VODKA 80 PROOF        532975.62
# 4                TENNESSEE WHISKIES        481602.74
# ..                              ...              ...
# 119           WHITE CREME DE MENTHE           719.58
# 120                        ANISETTE           586.88
# 121         IMPORTED VODKA - CHERRY           507.84
# 122              American Sloe Gins           414.63
# 123                   Flavored Gins             5.88
#
# [124 rows x 2 columns]

# %% [markdown]
# - Peak daily sales potential of each category, considering different packaging (Pack)

# %%
new10 = df.groupby(['Category_Name','Date'])['Sale_in_dollars'].sum().groupby(['Category_Name']).max().sort_values(ascending=False).reset_index()

# %%
new10
# Out:
#                       Category_Name  Sale_in_dollars
# 0                 CANADIAN WHISKIES        703903.62
# 1    DECANTERS & SPECIALTY PACKAGES        584169.40
# 2                TENNESSEE WHISKIES        399055.90
# 3                        SPICED RUM        354616.74
# 4                    VODKA 80 PROOF        353408.07
# ..                              ...              ...
# 119           WHITE CREME DE MENTHE           684.48
# 120                        ANISETTE           586.88
# 121         IMPORTED VODKA - CHERRY           507.84
# 122              American Sloe Gins           414.63
# 123                   Flavored Gins             5.88
#
# [124 rows x 2 columns]

# %% [markdown]
# - Peak daily sales for each category across all packs.

# %%
# Select top 10 categories from both datasets
new10_top10 = new10.head(10)

# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Create a bar plot
bar_width = 0.5  # Width of bars
index = range(len(new10_top10))  # X-axis index positions

# Plot bars for New10 (Category Only)
plt.barh([i + bar_width for i in index], new10_top10["Sale_in_dollars"], bar_width, label="New10 (Category)", color="lightcoral", alpha=0.9)

# Set labels and title
plt.xlabel("Total Peak Sales ($)", fontsize=12)
plt.ylabel("Category Name", fontsize=12)
plt.title("Top 10 Categories in highest amount of sales ($)", fontsize=14)
plt.yticks([i + bar_width for i in index], new10_top10["Category_Name"])  # Align category names

# Add legend
plt.legend()

# Invert y-axis for better readability
plt.gca().invert_yaxis()

# Show plot
plt.show()

# %% [markdown]
# ## 10 liquor categories with lowest sale

# %%
bottom10 = df.groupby(['Category_Name','Date'])['Sale_in_dollars'].sum().groupby(['Category_Name']).min().sort_values().reset_index()

# %%
bottom10.head(10)
# Out:
#                          Category_Name  Sale_in_dollars
# 0                 WHITE CREME DE CACAO             0.00
# 1                      CREME DE ALMOND             0.00
# 2                GREEN CREME DE MENTHE             0.00
# 3                   AMERICAN SLOE GINS             0.00
# 4  American Distilled Spirit Specialty             0.00
# 5                       PEACH BRANDIES             0.00
# 6                  DARK CREME DE CACAO             0.00
# 7                     APRICOT BRANDIES             4.85
# 8                    AMERICAN AMARETTO             5.00
# 9              TROPICAL FRUIT SCHNAPPS             5.51

# %% [markdown]
# ## Most popular consumed liquors

# %%
top10 = df.groupby(['Category_Name','Date'])['Volume_Sold_liters'].sum().groupby(['Category_Name']).max().sort_values(ascending=False).reset_index()

# %%
top10.head(10)
# Out:
#                       Category_Name  Volume_Sold_liters
# 0                 CANADIAN WHISKIES            69213.00
# 1                    VODKA 80 PROOF            44382.00
# 2                        SPICED RUM            23498.70
# 3    DECANTERS & SPECIALTY PACKAGES            20818.25
# 4                AMERICAN COCKTAILS            15949.88
# 5                TENNESSEE WHISKIES            14464.11
# 6                    IMPORTED VODKA            11929.03
# 7  PUERTO RICO & VIRGIN ISLANDS RUM            10916.10
# 8                    CREAM LIQUEURS            10833.60
# 9                   100 PROOF VODKA             9108.74

# %%
# Select top 10 categories from both datasets
top10 = top10.head(10)

# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Create a bar plot
bar_width = 0.5  # Width of bars
index = range(len(top10))  # X-axis index positions

# Plot bars for New10 (Category Only)
plt.bar(index, top10["Volume_Sold_liters"], bar_width, label="Top10 (Category)", color="blue", alpha=0.5)

# Set labels and title
plt.xlabel("Category Name", fontsize=12)
plt.ylabel("Total Peak Consumption in liters", fontsize=12)
plt.title("Top 10 Categories in highest Consumption of liquors liters", fontsize=14)
plt.xticks(index, top10["Category_Name"], rotation=45, ha='right')  # Align category names

plt.legend()
plt.show()

# %% [markdown]
# ## The Least Popular Consumed Liquors

# %%
Least10 = df.groupby(['Category_Name','Date'])['Volume_Sold_liters'].sum().groupby(['Category_Name']).min().sort_values().reset_index()

# %%
Least10.head(10)
# Out:
#                          Category_Name  Volume_Sold_liters
# 0  American Distilled Spirit Specialty                0.28
# 1                      SCOTCH WHISKIES                0.30
# 2                IMPORTED VODKA - MISC                0.38
# 3                     APRICOT BRANDIES                0.38
# 4              MISCELLANEOUS  BRANDIES                0.38
# 5                    IMPORTED AMARETTO                0.38
# 6            STRAIGHT BOURBON WHISKIES                0.50
# 7                    IMPORTED SCHNAPPS                0.50
# 8   MISC. AMERICAN CORDIALS & LIQUEURS                0.50
# 9                   TENNESSEE WHISKIES                0.50

# %%
Least10 = Least10.head(10)

plt.figure(figsize=(12,6))
sns.set_style('whitegrid')
index = range(len(Least10))

bar_width = 0.4

plt.bar(index, Least10['Volume_Sold_liters'],bar_width,label='Least10 (Category)',color='red',alpha = 0.3)

plt.xlabel('Category Name',fontsize=12)
plt.ylabel('Total consumption of liquor in liters',fontsize=12)
plt.title('Least 10 Categories with total consumption of liquor in liters',fontsize = 14)

plt.xticks(index, Least10['Category_Name'], rotation = 45, ha='right')
plt.yticks()

plt.show()

# %% [markdown]
# ## 10 Stores Sold the Most Liters of Liquor

# %%
store10 = df.groupby(['Store_Name','Date'])['Volume_Sold_liters'].sum().groupby(['Store_Name']).max().sort_values(ascending=False).reset_index()

# %%
store10.head(10)
# Out:
#                 Store_Name  Volume_Sold_liters
# 0  Hy-Vee Wine and Spirits            48075.15
# 1        Hy-Vee Food Store            29651.65
# 2    Costco Wholesale #788            26908.50
# 3          Sam's Club 8162            26147.50
# 4          Sam's Club 6979            24400.50
# 5          Sam's Club 6344            23604.00
# 6                Hy-Vee #3            19857.75
# 7     Hy-Vee Food Store #1            17442.20
# 8          Sam's Club 8238            16263.00
# 9   Costco Wholesale #1111            14179.50

# %%
store10 = store10.head(10)

# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Create a bar plot
bar_width = 0.5  # Width of bars
index = range(len(store10))  # X-axis index positions

# Plot bars for New10 (Category Only)
plt.barh([i + bar_width for i in index], store10["Volume_Sold_liters"], bar_width, label="store10 (Store)", color="green", alpha=0.8)

# Set labels and title
plt.xlabel("Total Volume sold in liters", fontsize=12)
plt.ylabel("Store Name", fontsize=12)
plt.title("Top 10 Stores in highest volume sold in liters", fontsize=14)
plt.yticks([i + bar_width for i in index], store10["Store_Name"])  # Align category names

# Add legend
plt.legend()

# Invert y-axis for better readability
plt.gca().invert_yaxis()

# Show plot
plt.show()

# %% [markdown]
# ## Most Liquor Consuming Cities

# %%
city10 = df.groupby(['City','Date'])['Volume_Sold_liters'].sum().groupby(['City']).max().sort_values(ascending=False).reset_index()

# %%
city10.head(10)
# Out:
#               City  Volume_Sold_liters
# 0  WEST DES MOINES            42061.25
# 1     CEDAR RAPIDS            41044.65
# 2       DES MOINES            35532.90
# 3       Des Moines            26359.90
# 4        DAVENPORT            25882.91
# 5  WINDSOR HEIGHTS            25619.25
# 6           ANKENY            24869.71
# 7  West Des Moines            24734.75
# 8          DUBUQUE            24703.82
# 9   COUNCIL BLUFFS            23339.10

# %%
city10 = city10.head(10)

# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Create a bar plot
bar_width = 0.5  # Width of bars
index = range(len(city10))  # X-axis index positions

# Plot bars for New10 (Category Only)
plt.barh([i + bar_width for i in index], city10["Volume_Sold_liters"], bar_width, label="city10 (city)", color="purple", alpha=0.8)

# Set labels and title
plt.xlabel("Total Volume sold in liters", fontsize=12)
plt.ylabel("City", fontsize=12)
plt.title("Top 10 Cities in highest volume sold in liters", fontsize=14)
plt.yticks([i + bar_width for i in index], city10["City"])  # Align category names

# Add legend
plt.legend()

# Invert y-axis for better readability
plt.gca().invert_yaxis()

# Show plot
plt.show()

# %% [markdown]
# ## The Highest Profit Contributor Liquor Categories

# %%
profit10 = df.groupby(['Category_Name','Date'])['State_Profit_per_bottle'].sum().groupby(['Category_Name']).max().sort_values(ascending=False).reset_index()

# %%
profit10.head(10)
# Out:
#                     Category_Name  State_Profit_per_bottle
# 0                  American Vodka                 15148.80
# 1               CANADIAN WHISKIES                  8648.88
# 2               Canadian Whiskies                  8060.11
# 3              TENNESSEE WHISKIES                  7487.50
# 4                  VODKA 80 PROOF                  7070.58
# 5       Straight Bourbon Whiskies                  6865.47
# 6  SINGLE BARREL BOURBON WHISKIES                  5858.37
# 7       STRAIGHT BOURBON WHISKIES                  5857.58
# 8                     Holiday VAP                  5621.53
# 9                         TEQUILA                  5452.78

# %%
profit10 = profit10.head(10)

plt.figure(figsize=(12,6))
sns.set_style('whitegrid')
index = range(len(profit10))

bar_width = 0.4

plt.bar(index, profit10['State_Profit_per_bottle'],bar_width,label='profit10 (Category)',color='red',alpha = 0.9)

plt.xlabel('Category Name',fontsize=12)
plt.ylabel('State Profit Total Bottle ($)',fontsize=12)
plt.title('The Highest Profit Contributor Liquor Categories',fontsize = 14)

plt.xticks(index, profit10['Category_Name'], rotation = 45, ha='right')
plt.yticks()

plt.show()

# %%
df.head()
# Out:
#    Invoice_Item_Number       Date Store_Number                  Store_Name  \
# 6         S28865700001 2015-11-09         2538        Hy-Vee Food Store #3
# 8         S29339300091 2015-11-30         2662       Hy-Vee Wine & Spirits
# 13        S28866900001 2015-11-11         3650  Spirits, Stogies and Stuff
# 18        S29134300126 2015-11-18         3723          J D Spirits Liquor
# 21        S29282800048 2015-11-23         2642     Hy-Vee Wine and Spirits
#
#          City   Category                   Category_Name Vendor_Number  \
# 6    WATERLOO  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
# 8   MUSCATINE  1701100.0  DECANTERS & SPECIALTY PACKAGES          65.0
# 13   HOLSTEIN  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
# 18      ONAWA  1081200.0                  CREAM LIQUEURS         305.0
# 21      PELLA  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
#
#                           Vendor_Name Item_Number  \
# ...

# %% [markdown]
# ## Sales of Liquor per Year and Month

# %%
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %%
year10 = df.groupby(['Year','Date'])['Sale_in_dollars'].sum().groupby(['Year']).sum().sort_values(ascending=False).reset_index()

year10 = year10.sort_values(by='Year')

# %%
year10.head(10)
# Out:
#    Year  Sale_in_dollars
# 3  2012     2.550630e+08
# 2  2013     2.579592e+08
# 1  2014     2.703822e+08
# 0  2015     2.840053e+08
# 4  2016     2.504565e+08
# 5  2017     1.476581e+08

# %%
year10 = year10.head(10)

plt.figure(figsize=(12,6))
sns.set_style('whitegrid')
index = range(len(year10))

bar_width = 0.4

plt.bar(index, year10['Sale_in_dollars'],bar_width,color='red',alpha = 0.9)

plt.plot(index, year10['Sale_in_dollars'], marker='o', linestyle='-', color='black', linewidth=0.1, markersize=6, label="Yearly Trend in sales")

# Add data labels on top of bars
for i, value in enumerate(year10['Sale_in_dollars']):
    plt.text(i, value + 10000, f"${value:,}", ha='center', fontsize=10, color='black')

plt.xlabel('Year',fontsize=12)
plt.ylabel('Total Sales in Million ($)',fontsize=12)
plt.title('Total Sales in dollars per Year',fontsize = 14)

plt.xticks(index, year10['Year'], rotation = 45, ha='right')
plt.yticks()

plt.show()

# %% [markdown]
# - Here, we can notice that the total sales in year 2017 were decreased significantly.

# %%
month10 = df.groupby(['Month','Date'])['Sale_in_dollars'].sum().groupby(['Month']).sum().sort_values(ascending=False).reset_index()

month10 = month10.sort_values(by='Month')

# %%
month10.head(10)
# Out:
#     Month  Sale_in_dollars
# 10      1     1.044249e+08
# 9       2     1.114493e+08
# 7       3     1.174836e+08
# 6       4     1.238620e+08
# 3       5     1.301846e+08
# 1       6     1.367383e+08
# 5       7     1.242275e+08
# 4       8     1.275177e+08
# 8       9     1.127683e+08
# 0      10     1.481416e+08

# %%
month10 = month10.head(10)

plt.figure(figsize=(20,12))
sns.set_style('whitegrid')
index = range(len(month10))

bar_width = 0.5

plt.bar(index, month10['Sale_in_dollars'],bar_width,color='green',alpha = 0.9)

plt.plot(index, month10['Sale_in_dollars'], marker='o', linestyle='-', color='black', linewidth=0.1, markersize=6, label="Monthly Trend in sales")

# Add data labels on top of bars
for i, value in enumerate(month10['Sale_in_dollars']):
    plt.text(i, value + 10000, f"${value:,}", ha='center', fontsize=10, color='black')

plt.xlabel('Month',fontsize=14)
plt.ylabel('Total Sales in Million ($)',fontsize=14)
plt.title('Total Sales in dollars per Month',fontsize = 16)

plt.xticks(index, month10['Month'], ha='right')
plt.yticks()

plt.show()

# %% [markdown]
# ## Stores per City

# %%
salespercity= (df.groupby('City')['Sale_in_dollars'].sum().to_frame().sort_values('Sale_in_dollars', ascending=False)).reset_index()

storespercity= df.groupby('City')['Store_Number'].nunique().to_frame().sort_values('Store_Number', ascending=False).reset_index()

storesalespercity = pd.merge(salespercity, storespercity, on='City', how='outer')

storesalespercity = storesalespercity.rename(columns={'Sale_in_dollars':'Total_Sales','Store_Number':'Number of Stores'})

# %%
salespercity.head(10)
# Out:
#               City  Sale_in_dollars
# 0       DES MOINES     1.423560e+08
# 1     CEDAR RAPIDS     8.008896e+07
# 2        DAVENPORT     5.806222e+07
# 3  WEST DES MOINES     4.328201e+07
# 4         WATERLOO     4.288150e+07
# 5        IOWA CITY     4.221010e+07
# 6   COUNCIL BLUFFS     3.826520e+07
# 7       SIOUX CITY     3.819163e+07
# 8       Des Moines     3.591711e+07
# 9          DUBUQUE     3.198280e+07

# %%
storespercity.head(10)
# Out:
#              City  Store_Number
# 0      DES MOINES           100
# 1    CEDAR RAPIDS            89
# 2      Des Moines            87
# 3    Cedar Rapids            82
# 4        WATERLOO            63
# 5       Davenport            52
# 6       DAVENPORT            50
# 7  COUNCIL BLUFFS            47
# 8        Waterloo            44
# 9  Council Bluffs            43

# %%
storesalespercity.head()
# Out:
#      City  Total_Sales  Number of Stores
# 0  ACKLEY    240870.00                 2
# 1   ADAIR    189448.44                 2
# 2    ADEL   1349899.18                 4
# 3   AFTON    137832.15                 1
# 4   AKRON    134999.66                 1

# %%
storespercity = storespercity.head(10)

# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Create a bar plot
bar_width = 0.5  # Width of bars
index = range(len(storespercity))  # X-axis index positions

# Plot bars for New10 (Category Only)
plt.barh([i + bar_width for i in index], storespercity["Store_Number"], bar_width, color="orange", alpha=0.8)

# Set labels and title
plt.xlabel("Stores Count", fontsize=12)
plt.ylabel("City", fontsize=12)
plt.title("Top 10 cities with highest number of stores", fontsize=14)
plt.yticks([i + bar_width for i in index], storespercity["City"])  # Align category names

# Add legend
#plt.legend()

# Invert y-axis for better readability
plt.gca().invert_yaxis()

# Show plot
plt.show()

# %% [markdown]
# ## Top 10 highest profit contributor

# %%
profitpercity= (df.groupby('Store_Name')['State_Profit_per_bottle'].sum().to_frame().sort_values('State_Profit_per_bottle', ascending=False)).reset_index()
profitpercity = pd.DataFrame(profitpercity)

# %%
profitpercity = profitpercity.head(10)

# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Create a bar plot
bar_width = 0.5  # Width of bars
index = range(len(profitpercity))  # X-axis index positions

# Plot bars for New10 (Category Only)
plt.barh([i + bar_width for i in index], profitpercity["State_Profit_per_bottle"], bar_width, color="yellow", alpha=0.9)

# Set labels and title
plt.xlabel("Profit ($)", fontsize=12)
plt.ylabel("Store", fontsize=12)
plt.title("Top 10 Stores with highest profits ($)", fontsize=14)
plt.yticks([i + bar_width for i in index], profitpercity["Store_Name"])  # Align category names

# Add legend
#plt.legend()

# Invert y-axis for better readability
plt.gca().invert_yaxis()

# Show plot
plt.show()

# %% [markdown]
# ## Profit per city

# %%
profitpercity= (df.groupby('City')['State_Profit_per_bottle'].sum().to_frame().sort_values('State_Profit_per_bottle', ascending=False)).reset_index()
profitpercity = pd.DataFrame(profitpercity)

# %%
profitpercity = profitpercity.head(10)

# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Create a bar plot
bar_width = 0.5  # Width of bars
index = range(len(profitpercity))  # X-axis index positions

# Plot bars for New10 (Category Only)
plt.barh([i + bar_width for i in index], profitpercity["State_Profit_per_bottle"], bar_width, color="brown", alpha=0.9)

# Set labels and title
plt.xlabel("Profit ($)", fontsize=12)
plt.ylabel("City", fontsize=12)
plt.title("Top 10 Stores with highest profits ($)", fontsize=14)
plt.yticks([i + bar_width for i in index], profitpercity["City"])  # Align category names

# Add legend
#plt.legend()

# Invert y-axis for better readability
plt.gca().invert_yaxis()

# Show plot
plt.show()

# %% [markdown]
# # Forecasting

# %%
df.head()
# Out:
#    Invoice_Item_Number       Date Store_Number                  Store_Name  \
# 6         S28865700001 2015-11-09         2538        Hy-Vee Food Store #3
# 8         S29339300091 2015-11-30         2662       Hy-Vee Wine & Spirits
# 13        S28866900001 2015-11-11         3650  Spirits, Stogies and Stuff
# 18        S29134300126 2015-11-18         3723          J D Spirits Liquor
# 21        S29282800048 2015-11-23         2642     Hy-Vee Wine and Spirits
#
#          City   Category                   Category_Name Vendor_Number  \
# 6    WATERLOO  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
# 8   MUSCATINE  1701100.0  DECANTERS & SPECIALTY PACKAGES          65.0
# 13   HOLSTEIN  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
# 18      ONAWA  1081200.0                  CREAM LIQUEURS         305.0
# 21      PELLA  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
#
#                           Vendor_Name Item_Number  \
# ...

# %% [markdown]
# ## 7 columns:
#
# - ### City Codes: Assign unique numeric codes to each city.
# - ### Number of Stores: Count unique stores in each city.
# - ### Total Bottle Volume: Sum of Bottle_Volume across all transactions.
# - ### State Profit Per Bottle: Sum up State_Profit_total_bottle across all transactions.
# - ### Bottles Sold: Total number of bottles sold.
# - ### Total Sales in Dollars: Total revenue from sales.
# - ### Sales per store: Total sales from each store.

# %%
df_forecasting = df

# %%
# Assign unique codes to each city
city_codes = {city: code for code, city in enumerate(df_forecasting['City'].unique())}
df_forecasting['City_Code'] = df_forecasting['City'].map(city_codes)

# %%
df_forecasting = df_forecasting.drop(columns={'Invoice_Item_Number','Store_Number','Vendor_Number','Vendor_Name','Item_Number','Item_Description'})

# %%
df_forecasting.head()
# Out:
#          Date                  Store_Name       City   Category  \
# 6  2015-11-09        Hy-Vee Food Store #3   WATERLOO  1701100.0
# 8  2015-11-30       Hy-Vee Wine & Spirits  MUSCATINE  1701100.0
# 13 2015-11-11  Spirits, Stogies and Stuff   HOLSTEIN  1701100.0
# 18 2015-11-18          J D Spirits Liquor      ONAWA  1081200.0
# 21 2015-11-23     Hy-Vee Wine and Spirits      PELLA  1701100.0
#
#                      Category_Name  Pack  Bottle_Volume  State_Bottle_Cost  \
# 6   DECANTERS & SPECIALTY PACKAGES     6           1500              11.62
# 8   DECANTERS & SPECIALTY PACKAGES    12            750              19.58
# 13  DECANTERS & SPECIALTY PACKAGES     6           1500              11.62
# 18                  CREAM LIQUEURS     1           6000              99.00
# 21  DECANTERS & SPECIALTY PACKAGES     6           1500              11.62
#
#     State_Bottle_Retail  Bottles_Sold  Sale_in_dollars  Volume_Sold_liters  \
# ...

# %%
df_forecasting.shape
# Out:
# (12573065, 18)

# %%
# Aggregating at city level with available columns
city_level_df = df.groupby('City').agg({
    'Store_Number': 'nunique',  # Count unique stores in each city
    'Bottles_Sold': 'sum',  # Total bottles sold
    'Sale_in_dollars': 'sum',  # Total sales
    'Volume_Sold_liters': 'sum',  # Total liters sold
    'State_Profit_total_bottle': 'sum'  # Total profit
}).reset_index()

# %%
# Renaming columns to match requested names
city_level_df.rename(columns={
    'Store_Number': 'number_of_stores',
    'State_Profit_total_bottle': 'State_Profit_per_bottle',
    'Sale_in_dollars': 'total_Sale_in_dollars',
    'Volume_Sold_liters': 'Volume_Sold_liters'
}, inplace=True)

# %%
# Adding city codes
city_array = pd.factorize(df['City'].unique())
city_array = (pd.DataFrame(city_array).T)
city_array.rename(columns={0 : "City Code", 1: "City"}, inplace=True)
city_level_df['City_Code'] = city_array['City Code'].astype(str).astype(int)

# %%
city_array.head()
# Out:
#   City Code       City
# 0         0   WATERLOO
# 1         1  MUSCATINE
# 2         2   HOLSTEIN
# 3         3      ONAWA
# 4         4      PELLA

# %%
# Calculating Sales Per Store
city_level_df['sales_per_store'] = city_level_df['total_Sale_in_dollars'] / city_level_df['number_of_stores']

# %%
city_level_df = city_level_df.drop(columns={'City'})

# %%
city_level_df.head()
# Out:
#    number_of_stores  Bottles_Sold  total_Sale_in_dollars  Volume_Sold_liters  \
# 0                 2         20456              240870.00            22411.89
# 1                 2         17592              189448.44            12615.19
# 2                 4        109292             1349899.18           107645.64
# 3                 1         12648              137832.15            10763.90
# 4                 1         13185              134999.66            10995.60
#
#    State_Profit_per_bottle  City_Code  sales_per_store
# 0                 80781.78          0       120435.000
# 1                 63395.73          1        94724.220
# 2                453384.59          2       337474.795
# 3                 46149.92          3       137832.150
# 4                 45242.17          4       134999.660

# %% [markdown]
# ## Correlation Analysis

# %%
plt.figure(figsize=(10,8))
sns.heatmap(city_level_df.corr(), cmap='Blues', annot=True,)
plt.show()

# %% [markdown]
# ## Interpretation:
# - Target total_sal_in_dollars highly depends on columns Bottles sold, volume sold in liters, state profit per bottle with 0.99
# - number of stores is the next highest with 0.84 and
# - sales per store is the least with 0.39
# - Also, there is a high correlation between independent features.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import linear_model
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
city_level_df.head()
# Out:
#    number_of_stores  Bottles_Sold  total_Sale_in_dollars  Volume_Sold_liters  \
# 0                 2         20456              240870.00            22411.89
# 1                 2         17592              189448.44            12615.19
# 2                 4        109292             1349899.18           107645.64
# 3                 1         12648              137832.15            10763.90
# 4                 1         13185              134999.66            10995.60
#
#    State_Profit_per_bottle  City_Code  sales_per_store
# 0                 80781.78          0       120435.000
# 1                 63395.73          1        94724.220
# 2                453384.59          2       337474.795
# 3                 46149.92          3       137832.150
# 4                 45242.17          4       134999.660

# %%
X = city_level_df[['State_Profit_per_bottle', 'number_of_stores', 'Volume_Sold_liters', 'Bottles_Sold', 'sales_per_store']]
y = city_level_df['total_Sale_in_dollars']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ### Ridge Regression Predictor of Future Sales

# %%
# Define alpha values
alpha_range = 10.**np.arange(-2, 3)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Fit RidgeCV
ridgeregcv = RidgeCV(alphas=alpha_range, scoring='neg_mean_squared_error')
ridgeregcv.fit(X_train_scaled, y_train)

# Get the best alpha
best_alpha = ridgeregcv.alpha_
print("Best alpha:", best_alpha)
# Out:
# Best alpha: 0.1

# %%
# Fit Ridge Regression without 'normalize' parameter
ridgereg = Ridge(alpha=0.01)
ridgereg.fit(X_train_scaled, y_train)

# Predict
y_pred = ridgereg.predict(X_test_scaled)

# Print predictions and RMSE
print(y_pred)
print('--------')
print('RMSE =', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# [-8.10270023e+04  2.72462697e+05 -6.05454805e+04  1.52237153e+07
#   1.02312784e+05  2.36837766e+05 -7.71213460e+04  2.64657641e+05
#   5.77784858e+07  2.64049512e+04  3.69638113e+05 -7.47038411e+04
#   4.79747562e+06  5.04591693e+05  4.54053042e+04  2.85167765e+06
#  -3.61260202e+04  1.85586810e+05  1.68214159e+05  5.39763688e+06
#  -2.11276707e+04  2.05289847e+05 -7.79664740e+04  1.49513643e+05
#   2.79486599e+04  8.84311617e+05  3.77259515e+05  3.64834605e+05
#   2.06440152e+05  3.32908340e+05  4.56325993e+05  1.61466896e+06
#   2.04830438e+05  2.95044997e+05 -6.51318018e+04  3.79377777e+04
#  -6.26653786e+04  5.20654440e+03  9.68871171e+05  2.69815925e+05
#   4.48683677e+05  5.06229871e+06  1.35208513e+06 -7.21843210e+04
#   1.95430677e+05 -5.04682665e+04  1.04232561e+05  2.37565479e+05
#   9.55274237e+04  6.65565256e+04 -8.28765660e+04  4.25268367e+04
#   4.05317349e+04  2.01511679e+05  1.97543556e+04 -3.98585551e+04
# ...

# %%
# examine the coefficients
rc = ridgeregcv.coef_
print(X.columns, rc)
# Out:
# Index(['State_Profit_per_bottle', 'number_of_stores', 'Volume_Sold_liters',
#        'Bottles_Sold', 'sales_per_store'],
#       dtype='object') [ 9029049.53922007  1176942.48394798 -2821544.26529944   511007.64183877
#    138093.50182593]

# %%
accuracy = metrics.r2_score(y_test, y_pred)
mse= metrics.mean_squared_error(y_test, y_pred)
mae=metrics.mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print(accuracy)
print(mse)
print(mae)
print(rmse)

plt.scatter(y_test, y_pred)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Ridge Regression Predictor of Future Sales', fontsize='x-large')
plt.show()
# Out:
# 0.9979204950221584
# 117190109853.82364
# 153939.56169355678
# 342330.4103550014

# %%
city_level_df.head()
# Out:
#    number_of_stores  Bottles_Sold  total_Sale_in_dollars  Volume_Sold_liters  \
# 0                 2         20456              240870.00            22411.89
# 1                 2         17592              189448.44            12615.19
# 2                 4        109292             1349899.18           107645.64
# 3                 1         12648              137832.15            10763.90
# 4                 1         13185              134999.66            10995.60
#
#    State_Profit_per_bottle  City_Code  sales_per_store
# 0                 80781.78          0       120435.000
# 1                 63395.73          1        94724.220
# 2                453384.59          2       337474.795
# 3                 46149.92          3       137832.150
# 4                 45242.17          4       134999.660

# %% [markdown]
# ### Ordinary Least Squares regression

# %%
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
import numpy as np 
dep = city_level_df['total_Sale_in_dollars']
indep = city_level_df[['City_Code','number_of_stores','Bottles_Sold','Volume_Sold_liters']]
indep = sm.add_constant(indep)
model = sm.OLS(dep,indep)
results = model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     total_Sale_in_dollars   R-squared:                       0.993
# Model:                               OLS   Adj. R-squared:                  0.993
# Method:                    Least Squares   F-statistic:                 2.876e+04
# Date:                   Tue, 04 Mar 2025   Prob (F-statistic):               0.00
# Time:                           19:00:10   Log-Likelihood:                -11623.
# No. Observations:                    787   AIC:                         2.326e+04
# Df Residuals:                        782   BIC:                         2.328e+04
# Df Model:                              4
# Covariance Type:               nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -2.246e+05   4.74e+04     -4.734      0.000   -3.18e+05   -1.31e+05
# ...

# %% [markdown]
# ### Linear Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size=0.3, random_state=1)

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
y_pred = lm.predict(indep)
print(y_pred)
# Out:
# [ 3.96242124e+05  3.19394513e+05  1.71611529e+06  1.47935485e+05
#   1.52432716e+05  1.54835561e+06  5.05310914e+05  4.21857008e+06
#   3.79632922e+05  3.73806863e+04  3.11069619e+04  3.51915086e+05
#   9.86136663e+06  3.67473447e+03  3.07104254e+07  2.88451261e+06
#   4.49799331e+05  1.93836887e+07  5.48468221e+05  1.59956035e+05
#   3.50349584e+05  7.81056894e+04  1.74181835e+06  4.77385532e+06
#   8.79823040e+05  4.30345276e+04  1.43081673e+06  3.13732726e+05
#   1.55638747e+05  4.65355899e+05  1.73211116e+04  3.88386720e+04
#   6.42381744e+03  3.23197408e+05  3.63958035e+03  4.01773077e+03
#   1.84563415e+05  9.15633533e+05  1.66377705e+05  7.93289315e+03
#   2.41328264e+06  7.27487612e+03  8.13279901e+06  7.11368544e+05
#   1.93215932e+05  5.86376947e+06  2.18068125e+04  1.47231803e+05
#   1.71385120e+04  8.32112348e+04  6.34768346e+05  3.12549513e+04
#   1.39789352e+06  2.36469925e+05 -1.25259007e+02  4.44915739e+05
# ...

# %%
from sklearn.model_selection import KFold, cross_val_score, cross_val_predict
scores = cross_val_score(lm, X_test, y_test, cv=5)
print(scores)
print(np.mean(scores))
# Out:
# [0.99249674 0.99557062 0.98873463 0.98433349 0.99297926]
# 0.9908229458615819

# %%
plt.scatter(dep, y_pred, marker='+', color='r')
plt.xlabel("True Values")
plt.ylabel("Predictions")
accuracy = metrics.r2_score(dep, y_pred)
mse= metrics.mean_squared_error(dep, y_pred)
mae=metrics.mean_absolute_error(dep,y_pred)
rmse=np.sqrt(metrics.mean_squared_error(dep, y_pred))
print(accuracy)
print(mse)
print(mae)
print(rmse)
# Out:
# 0.992932835923616
# 411897186904.56036
# 232813.5146279773
# 641792.1679987692

# %%
city_level_df.head()
# Out:
#    number_of_stores  Bottles_Sold  total_Sale_in_dollars  Volume_Sold_liters  \
# 0                 2         20456              240870.00            22411.89
# 1                 2         17592              189448.44            12615.19
# 2                 4        109292             1349899.18           107645.64
# 3                 1         12648              137832.15            10763.90
# 4                 1         13185              134999.66            10995.60
#
#    State_Profit_per_bottle  City_Code  sales_per_store
# 0                 80781.78          0       120435.000
# 1                 63395.73          1        94724.220
# 2                453384.59          2       337474.795
# 3                 46149.92          3       137832.150
# 4                 45242.17          4       134999.660

# %%
# Accuracy for Annual Predicted Sales for 2016
accuracy=metrics.r2_score(city_level_df['total_Sale_in_dollars'], y_pred)
print(accuracy)
# Error for Annual Predicted Sales for 2016
Percent_Prediction_Error = (np.sum(city_level_df['total_Sale_in_dollars'])- np.sum(y_pred))/np.sum(city_level_df['total_Sale_in_dollars'])*100
print(Percent_Prediction_Error)
# Out:
# 0.992932835923616
# 1.2466864917105138

# %%
const = -224600
CityCode = 6.9239
NumberofStores = 129800
BottlesSold = 4.1658
VolumeSoldGallons = 8.5001

# %%
# Annual Predicted Sales for 2017
new_y_pred =const + CityCode*city_level_df['City_Code'] + NumberofStores*city_level_df['number_of_stores'] + BottlesSold*city_level_df['Bottles_Sold'] + VolumeSoldGallons*city_level_df['Volume_Sold_liters']
np.sum(new_y_pred)
# Out:
# 1465658681.582401

# %%
# Accuracy for Annual Predicted Sales for 2017
accuracy=metrics.r2_score(city_level_df['total_Sale_in_dollars'], new_y_pred)
print(accuracy)
# Out:
# 0.9932484665708478

# %%
# Error for Annual Predicted Sales for 2017
Percent_Prediction_Error = (np.sum(city_level_df['total_Sale_in_dollars'])- np.sum(new_y_pred))/np.sum(city_level_df['total_Sale_in_dollars'])*100
print(Percent_Prediction_Error)
# Out:
# -0.009164652258587655

# %%
df.head()
# Out:
#    Invoice_Item_Number       Date Store_Number                  Store_Name  \
# 6         S28865700001 2015-11-09         2538        Hy-Vee Food Store #3
# 8         S29339300091 2015-11-30         2662       Hy-Vee Wine & Spirits
# 13        S28866900001 2015-11-11         3650  Spirits, Stogies and Stuff
# 18        S29134300126 2015-11-18         3723          J D Spirits Liquor
# 21        S29282800048 2015-11-23         2642     Hy-Vee Wine and Spirits
#
#          City   Category                   Category_Name Vendor_Number  \
# 6    WATERLOO  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
# 8   MUSCATINE  1701100.0  DECANTERS & SPECIALTY PACKAGES          65.0
# 13   HOLSTEIN  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
# 18      ONAWA  1081200.0                  CREAM LIQUEURS         305.0
# 21      PELLA  1701100.0  DECANTERS & SPECIALTY PACKAGES         962.0
#
#                           Vendor_Name Item_Number  \
# ...

# %% [markdown]
# ## Time Series Analysis

# %%
## Time Series Analysis

y = df.groupby('Date')['Sale_in_dollars'].sum().resample('MS').mean()
y.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_forecasting.head()
# Out:
#          Date                  Store_Name       City   Category  \
# 6  2015-11-09        Hy-Vee Food Store #3   WATERLOO  1701100.0
# 8  2015-11-30       Hy-Vee Wine & Spirits  MUSCATINE  1701100.0
# 13 2015-11-11  Spirits, Stogies and Stuff   HOLSTEIN  1701100.0
# 18 2015-11-18          J D Spirits Liquor      ONAWA  1081200.0
# 21 2015-11-23     Hy-Vee Wine and Spirits      PELLA  1701100.0
#
#                      Category_Name  Pack  Bottle_Volume  State_Bottle_Cost  \
# 6   DECANTERS & SPECIALTY PACKAGES     6           1500              11.62
# 8   DECANTERS & SPECIALTY PACKAGES    12            750              19.58
# 13  DECANTERS & SPECIALTY PACKAGES     6           1500              11.62
# 18                  CREAM LIQUEURS     1           6000              99.00
# 21  DECANTERS & SPECIALTY PACKAGES     6           1500              11.62
#
#     State_Bottle_Retail  Bottles_Sold  Sale_in_dollars  Volume_Sold_liters  \
# ...

# %%
V_Liters = pd.DataFrame({'V_Liters':df_forecasting.groupby(['City'])['Volume_Sold_liters'].sum()})
bottles = pd.DataFrame({'Bottles':df_forecasting.groupby(['City'])['Bottles_Sold'].sum()})

sales_y16q1 = pd.DataFrame({'Q1Y16':df_forecasting[(df_forecasting.Date >= '2016-01-01') & (df_forecasting.Date < '2016-04-01')].groupby(['City'])['Sale_in_dollars'].sum()})
sales_y16q2 = pd.DataFrame({'Q2Y16':df_forecasting[(df_forecasting.Date >= '2016-04-01') & (df_forecasting.Date < '2016-07-01')].groupby(['City'])['Sale_in_dollars'].sum()})
sales_y16q3 = pd.DataFrame({'Q3Y16':df_forecasting[(df_forecasting.Date >= '2016-07-01') & (df_forecasting.Date < '2016-10-01')].groupby(['City'])['Sale_in_dollars'].sum()})
sales_y16q4 = pd.DataFrame({'Q4Y16':df_forecasting[(df_forecasting.Date >= '2016-10-01') & (df_forecasting.Date < '2017-01-01')].groupby(['City'])['Sale_in_dollars'].sum()})

sales_y17q1 = pd.DataFrame({'Q1Y17':df_forecasting[(df_forecasting.Date >= '2017-01-01') & (df_forecasting.Date < '2017-04-01')].groupby(['City'])['Sale_in_dollars'].sum()})
sales_y17q2 = pd.DataFrame({'Q2Y17':df_forecasting[(df_forecasting.Date >= '2017-04-01') & (df_forecasting.Date < '2017-07-01')].groupby(['City'])['Sale_in_dollars'].sum()})
sales_y17q3 = pd.DataFrame({'Q3Y17':df_forecasting[(df_forecasting.Date >= '2017-07-01') & (df_forecasting.Date < '2017-10-01')].groupby(['City'])['Sale_in_dollars'].sum()})

city_sales = pd.concat([bottles, V_Liters ,sales_y16q1, sales_y16q2, sales_y16q3, sales_y16q4, sales_y17q1, sales_y17q2, sales_y17q3], axis =1, join = 'outer').sort_values('V_Liters', ascending=False).reset_index()
city_sales.fillna(0,inplace = True)
city_sales['Vol Mean'] = city_sales['V_Liters'] / city_sales['Bottles']
city_sales.head()
# Out:
#            City   Bottles    V_Liters       Q1Y16       Q2Y16  Q3Y16  Q4Y16  \
# 0    DES MOINES  11196517  9064567.99  8692835.44  3201964.75    0.0    0.0
# 1  CEDAR RAPIDS   6271420  5662682.67  4559655.05  1459036.85    0.0    0.0
# 2     DAVENPORT   5102840  3989787.63  3244140.18  1130990.35    0.0    0.0
# 3      WATERLOO   4016975  2899989.24  2389772.66   833066.89    0.0    0.0
# 4     IOWA CITY   3203256  2853336.90  2380681.68   863770.05    0.0    0.0
#
#    Q1Y17  Q2Y17  Q3Y17  Vol Mean
# 0    0.0    0.0    0.0  0.809588
# 1    0.0    0.0    0.0  0.902935
# 2    0.0    0.0    0.0  0.781876
# 3    0.0    0.0    0.0  0.721934
# 4    0.0    0.0    0.0  0.890761

# %%
increment = city_sales.Q3Y17.sum()/city_sales.Q3Y16.sum()
print ('The increment from 2016 to 2017:', increment)
Q4Y17 = city_sales.Q4Y16.sum()*city_sales.Q3Y17.sum()/city_sales.Q3Y16.sum()
print ('Forecast of sales for Q4 Y17: $', Q4Y17)
FY17 = city_sales.Q1Y17.sum() + city_sales.Q2Y17.sum() + city_sales.Q3Y17.sum() + Q4Y17
print ('The forecast for the fiscal year 2017: $', FY17)
# Out:
# The increment from 2016 to 2017: 0.7372371574910831
# Forecast of sales for Q4 Y17: $ 36192907.16870062
# The forecast for the fiscal year 2017: $ 168093908.83870062

# %%
X = city_sales[['Q3Y16', 'Vol Mean']]
y = city_sales.Q3Y17

# create training and testing vars
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (550, 2) (550,)
# (237, 2) (237,)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
print(predictions)
print(X_train.shape)
print(y_train.shape)
# Out:
# [1.57927515e+04 1.02488647e+05 3.97822850e+05 2.05053285e+04
#  8.98241023e+04 4.40547890e+03 3.47781690e+03 2.71782434e+03
#  4.79692295e+03 3.68925722e+04 3.64342612e+03 7.72729195e+03
#  2.74566715e+04 9.30546744e+03 6.74084451e+03 2.44165976e+03
#  7.62287350e+04 3.32366012e+03 6.03866782e+03 1.40047038e+03
#  5.50036843e+03 1.41976746e+04 3.81267664e+03 2.05724536e+03
#  3.67311201e+04 5.04027177e+03 4.22736754e+03 2.31684362e+03
#  2.63989428e+03 2.50510697e+03 6.92881898e+03 1.84349792e+03
#  2.00670538e+03 2.73794444e+03 2.56693639e+03 2.96284323e+03
#  1.02751378e+03 2.95078880e+03 1.97999289e+03 1.91604253e+03
#  2.19208895e+03 4.50925703e+03 2.25486155e+05 1.77174350e+03
#  2.39224843e+04 1.88264583e+03 9.84921095e+04 2.25802351e+03
#  3.28244722e+03 9.96606887e+04 2.45891194e+03 2.09114403e+03
#  9.39326125e+03 1.46267503e+05 4.52653774e+03 1.40604588e+04
#  3.04936545e+03 2.82521272e+03 1.95530319e+03 3.73641391e+03
# ...

# %%
r2 = r2_score(y_test, predictions)
print("R² Score:", r2)

rmse = np.sqrt(mean_squared_error(y_test, predictions))
print("RMSE:", rmse)

mae = mean_absolute_error(y_test, predictions)
print("MAE:", mae)
# Out:
# R² Score: 0.9779825202354898
# RMSE: 20160.125963871254
# MAE: 7296.310785332404
